-- %% [markdown]
-- # [dbo].[TblDetallePedido]

-- %%
USE [CONTROL]
GO

-- %%
/****** Object:  Table [dbo].[TblDetallePedido]    Script Date: 28/08/2023 7:05:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblDetallePedido](
	[Id_Detalle_Pedido] [int] NOT NULL,
	[Id_Pedido] [int] NULL,
	[Sku] [int] NULL,
	[Descripcion] [nvarchar](50) NULL,
	[cantidad] [int] NULL,
	[Unidad_Empaque] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Detalle_Pedido] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TblEstadoProducto]

-- %%
/****** Object:  Table [dbo].[TblEstadoProducto]    Script Date: 28/08/2023 7:05:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblEstadoProducto](
	[Id_estado] [int] NOT NULL,
	[Descripcion] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_estado] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TblPedido]

-- %%
/****** Object:  Table [dbo].[TblPedido]    Script Date: 28/08/2023 7:05:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblPedido](
	[Id_Pedido] [int] NOT NULL,
	[Id_Ruta] [int] NULL,
	[Nombre_Cliente] [nvarchar](50) NULL,
	[Direccion] [nvarchar](50) NULL,
	[Ciudad] [nvarchar](50) NULL,
	[Barrio] [nvarchar](50) NULL,
	[Fecha_Pedido] [date] NULL,
	[Telefono] [bigint] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Pedido] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TblRuta]

-- %%
/****** Object:  Table [dbo].[TblRuta]    Script Date: 28/08/2023 7:05:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblRuta](
	[id_ruta] [int] NOT NULL,
	[fecha_generacion] [date] NOT NULL,
	[estado_ruta] [nchar](10) NOT NULL,
 CONSTRAINT [PK_TblRuta] PRIMARY KEY CLUSTERED 
(
	[id_ruta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TblShipment]

-- %%
/****** Object:  Table [dbo].[TblShipment]    Script Date: 28/08/2023 7:05:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblShipment](
	[Id_Shipment] [int] NOT NULL,
	[Fecha_Despacho] [date] NULL,
	[Tipo_Vehiculo] [nvarchar](10) NULL,
	[Placa_Vehiculo] [nvarchar](50) NULL,
	[Nombre_Conductor] [nvarchar](50) NULL,
	[Muelle] [int] NULL,
	[id_transportadora] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Shipment] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TblTipoVehiculo]

-- %%
/****** Object:  Table [dbo].[TblTipoVehiculo]    Script Date: 28/08/2023 7:05:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblTipoVehiculo](
	[Id_Tipo_Vehiculo] [nvarchar](10) NOT NULL,
	[Descripcion_Vehiculo] [nvarchar](50) NULL,
	[Capacidad_Carga] [nvarchar](50) NULL,
	[Fecha_Creacion] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Tipo_Vehiculo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TblTransportadora]

-- %%
/****** Object:  Table [dbo].[TblTransportadora]    Script Date: 28/08/2023 7:05:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblTransportadora](
	[Id_Transportadora] [int] NOT NULL,
	[Nombre_Transportadora] [nvarchar](50) NULL,
	[Fecha_Creacion] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Transportadora] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TblUsuario]

-- %%
/****** Object:  Table [dbo].[TblUsuario]    Script Date: 28/08/2023 7:05:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblUsuario](
	[IdUsuario] [int] IDENTITY(1,1) NOT NULL,
	[FechaAlta] [datetime] NULL,
	[Email] [varchar](250) NULL,
	[Password] [varbinary](32) NULL,
	[FechaBaja] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[IdUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__TblDetall__Id_Pe__52593CB8]

-- %%
ALTER TABLE [dbo].[TblDetallePedido]  WITH CHECK ADD FOREIGN KEY([Id_Pedido])
REFERENCES [dbo].[TblPedido] ([Id_Pedido])
GO

-- %% [markdown]
-- # [FK__TblPedido__Id_Ru__4F7CD00D]

-- %%
ALTER TABLE [dbo].[TblPedido]  WITH CHECK ADD FOREIGN KEY([Id_Ruta])
REFERENCES [dbo].[TblRuta] ([id_ruta])
GO

-- %% [markdown]
-- # [FK__TblShipme__id_tr__5FB337D6]

-- %%
ALTER TABLE [dbo].[TblShipment]  WITH CHECK ADD FOREIGN KEY([id_transportadora])
REFERENCES [dbo].[TblTransportadora] ([Id_Transportadora])
GO

-- %% [markdown]
-- # [FK__TblShipme__Tipo___5EBF139D]

-- %%
ALTER TABLE [dbo].[TblShipment]  WITH CHECK ADD FOREIGN KEY([Tipo_Vehiculo])
REFERENCES [dbo].[TblTipoVehiculo] ([Id_Tipo_Vehiculo])
GO

-- %% [markdown]
-- # [dbo].[sp_ControlErrores]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ControlErrores]    Script Date: 28/08/2023 7:05:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- =============================================
-- Author:		<Author,,Name>
-- Create date: <Create Date,,>
-- Description:	<Description,,>
-- =============================================
CREATE PROCEDURE [dbo].[sp_ControlErrores]
	-- Add the parameters for the stored procedure here
	
AS
BEGIN
	-- SET NOCOUNT ON added to prevent extra result sets from
	-- interfering with SELECT statements.
	SET NOCOUNT ON;

    -- Insert statements for procedure here
	SELECT * from dbo.TblUsuario
END
GO

-- %% [markdown]
-- # [dbo].[spUsuarioInsert]

-- %%
/****** Object:  StoredProcedure [dbo].[spUsuarioInsert]    Script Date: 28/08/2023 7:05:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE    PROCEDURE  [dbo].[spUsuarioInsert]
(
	@Email varchar(250),
	@Password varchar(30)
)
AS
BEGIN 

	SET NOCOUNT ON;
	BEGIN TRY
		DECLARE @PasswordHash varbinary(32);
		select @PasswordHash= HASHBYTES('SHA2_256',@Password);

		INSERT INTO dbo.TblUsuario
		(FechaAlta, Email,Password)
		values(GETDATE(),@email,@PasswordHash);
	END TRY

	BEGIN CATCH
		execute dbo.sp_ControlErrores;
	END CATCH
END 
GO

-- %% [markdown]
-- # [dbo].[spUsuarioSetPassword]

-- %%
/****** Object:  StoredProcedure [dbo].[spUsuarioSetPassword]    Script Date: 28/08/2023 7:05:16 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE   PROCEDURE [dbo].[spUsuarioSetPassword]
(
	@Email varchar(250),
	@OldPassword varchar(30),
	@NewPassword varchar(30)
)
AS
BEGIN
	SET NOCOUNT ON;
	BEGIN TRY
	
		DECLARE @OldHashSegunUsuario varbinary(32);
		SELECT  @OldHashSegunUsuario= HASHBYTES('SHA2_256',@OldPassword);

		DECLARE  @Coincide int =0;
		SELECT  @Coincide=COUNT(*) FROM dbo.TblUsuario where Password=@OldHashSegunUsuario;
		IF @Coincide=0
		BEGIN 
			SELECT 0; RETURN;
		END

		--si ha coincidido, se establece un nuevo password
		DECLARE @NuevoHash varbinary (32);
		SELECT @NuevoHash= HASHBYTES('SHA2_256', @NewPassword);
		UPDATE dbo.TblUsuario set Password=@NuevoHash WHERE  Email=@Email;
		SELECT 1; RETURN;
	END TRY
	BEGIN CATCH
		execute dbo.sp_ControlErrores;
	END CATCH
END
GO
